# %% [markdown]
# # 加载招聘数据集

# %%
import pandas as pd
data = pd.read_csv(r"../database/拉勾网2023招聘数据.csv")
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29500 entries, 0 to 29499
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   keyword            29500 non-null  object
#  1   positionName       29500 non-null  object
#  2   companyFullName    29500 non-null  object
#  3   companySize        29036 non-null  object
#  4   industryField      28222 non-null  object
#  5   financeStage       29036 non-null  object
#  6   companyLabelList   29500 non-null  object
#  7   firstType          29500 non-null  object
#  8   secondType         29500 non-null  object
#  9   thirdType          29500 non-null  object
#  10  positionLables     29500 non-null  object
#  11  createTime         29500 non-null  object
#  12  city               29500 non-null  object
#  13  district           29437 non-null  object
#  14  salary             29500 non-null  object
#  15  workYear           29500 non-null  object
# ...

# %%
pd.set_option('display.max_rows', None)
data["keyword"] = data["keyword"].str.strip().str.upper()
data["keyword"] = data["keyword"].replace("PHP工程师", "PHP")
data["keyword"].value_counts()
# Out:
# keyword
# C             2790
# JAVA          2282
# 前端工程师         2223
# PYTHON        2095
# 后端开发          1088
# PHP           1012
# IOS            889
# 数据挖掘           874
# ANDROID        850
# 数据可视化          829
# 网络             812
# GO             729
# HTML5          723
# 运维             712
# 大数据工程师         675
# 图像处理           642
# SCALA          608
# 数据分析处理         606
# NOSQL          603
# 数据清洗           595
# 嵌入式            566
# SERVER         555
# 测试工程师          527
# .NET           514
# WEB            458
# PERL           451
# HADOOP         426
# SHELL          342
# 深度学习           334
# 数据应用开发         318
# 机器学习           299
# RUBY           263
# 精准推荐           247
# 自然语言处理         237
# JAVASCRIPT     231
# 移动开发           228
# 数据采集           203
# 语音识别           164
# 数据标注           138
# NODE.JS        129
# 图数据库           127
# 爬虫             123
# 智能应用           117
# SPARK           98
# 算法工程师           94
# 人工智能            72
# FLASH           71
# ...
